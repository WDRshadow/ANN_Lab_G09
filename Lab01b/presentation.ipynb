# %% [markdown]
# # Lab 1b: Multi-Layer Perceptron
#
# Import the test classes from the two parts of the lab.

# %%
import Lab01b.part1 as p1
import Lab01b.part2 as p2

test_1 = p1.Test()
test_2 = p2.Test()

# %% [markdown]
# ## Part 1: Implementing Multi-Layer Perceptron
#
# ### 1. Simple Multi-Layer Perceptron

# %%
test_1.test()
# Out:
# Test Loss: 0.05670583968740555

# %% [markdown]
# ### 2. Multi-Layer Perceptron with removed data cases

# %%
test_1.test_remove_case()
# Out:
# Test Loss: 0.06709948832504616
# Test Loss: 0.009717521563167178
# Test Loss: 0.14176768959729993

# %% [markdown]
# ### 3. Multi-Layer Perceptron with different hidden layer neurons

# %%
test_1.test_hidden_dim_case()
# Out:
# Test Loss: 0.5978889464627335
# Test Loss: 0.5607561557994162
# Test Loss: 0.05801752643344814
# Test Loss: 0.0597687330455979
# Test Loss: 0.053182812142480565
# Test Loss: 0.058195061877363924

# %% [markdown]
# ### 4. Randomly initialized weights

# %%
test_1.test_random_initial_weights()
# Out:
# Test Loss: 0.08199894729719638
# Test Loss: 0.07254846466431052
# Test Loss: 0.788956465467551
# Test Loss: 0.07286356684851812
# Test Loss: 0.07244376574200685
# Test Loss: 0.07844120460759313
# Test Loss: 0.0734140911057663
# Test Loss: 0.07248449942925445
# Test Loss: 0.07328353081644101
# Test Loss: 0.6139368626439191

# %% [markdown]
# ### 5. Approximated Gaussian function

# %%
test_1.test_gauss()
# Out:
# Test Loss: 0.00241042462760828

# %% [markdown]
# ### 6. Gaussian function with different percentage of training data

# %%
test_1.test_gauss_different_percentage()
# Out:
# Test Loss: 0.052804515380997355
# Test Loss: 0.007297559750014848
# Test Loss: 0.005199846968428643
# Test Loss: 0.002718700645726006
# Test Loss: 0.004033862267452763
# Test Loss: 0.0035764524621129013
# Test Loss: 0.003325839575792317

# %% [markdown]
# ### 7. Encoder

# %%
test_1.test_encoder()
# Out:
# Test Loss: 0.07263890270951139
# Test Loss: 0.0003213760379218722

# %% [markdown]
# ## Part 2: MLP with PyTorch
#
# ### 1. Simple Multi-Layer Perceptron

# %%
test_2.test()
# Out:
# Early stopping at epoch 3087
# Test Loss: 0.08454015851020813

# %% [markdown]
# ### 2. Multi-Layer Perceptron with different hidden layer neurons

# %%
test_2.test_dim_cases()
# Out:
# Testing with h1=3, h2=2
# Early stopping at epoch 2522
# Test Loss: 0.08475572615861893
# Testing with h1=3, h2=4
# Early stopping at epoch 4584
# Test Loss: 0.08455227315425873
# Testing with h1=3, h2=6
# Early stopping at epoch 5076
# Test Loss: 0.08455510437488556
# Testing with h1=4, h2=2
# Early stopping at epoch 3854
# Test Loss: 0.08454132080078125
# Testing with h1=4, h2=4
# Early stopping at epoch 1059
# Test Loss: 0.08512063324451447
# Testing with h1=4, h2=6
# Early stopping at epoch 821
# Test Loss: 0.08462776243686676
# Testing with h1=5, h2=2
# Early stopping at epoch 4172
# Test Loss: 0.08452929556369781
# Testing with h1=5, h2=4
# Early stopping at epoch 873
# Test Loss: 0.08514868468046188
# Testing with h1=5, h2=6
# Early stopping at epoch 1290
# Test Loss: 0.08453282713890076

# %% [markdown]
# ### 3. Train with Gaussian noise

# %%
test_2.test_gaussian_noise()
# Out:
# Testing with noise=0.05, h2=3
# Early stopping at epoch 4754
# Test Loss: 0.08453833311796188
# Testing with noise=0.05, h2=6
# Early stopping at epoch 2813
# Test Loss: 0.08452989161014557
# Testing with noise=0.05, h2=9
# Early stopping at epoch 1040
# Test Loss: 0.08456061780452728
# Testing with noise=0.15, h2=3
# Early stopping at epoch 1084
# Test Loss: 0.08462340384721756
# Testing with noise=0.15, h2=6
# Early stopping at epoch 2429
# Test Loss: 0.08453818410634995
# Testing with noise=0.15, h2=9
# Early stopping at epoch 1962
# Test Loss: 0.08454027026891708

# %%
test_2.test_gaussian_noise(regularization=0.0001)
# Out:
# Testing with noise=0.05, h2=3
# Early stopping at epoch 718
# Test Loss: 0.08549673110246658
# Testing with noise=0.05, h2=6
# Early stopping at epoch 9293
# Test Loss: 0.13415710628032684
# Testing with noise=0.05, h2=9
# Early stopping at epoch 9601
# Test Loss: 0.13331320881843567
# Testing with noise=0.15, h2=3
# Early stopping at epoch 13029
# Test Loss: 0.12891435623168945
# Testing with noise=0.15, h2=6
# Early stopping at epoch 728
# Test Loss: 0.0848315879702568
# Testing with noise=0.15, h2=9
# Early stopping at epoch 524
# Test Loss: 0.08474493771791458
