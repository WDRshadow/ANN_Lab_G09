# %% [markdown]
# # Lab 1b: Multi-Layer Perceptron
#
# Import the test classes from the two parts of the lab.

# %%
import Lab01b.part1 as p1
import Lab01b.part2 as p2

test_1 = p1.Test()
test_2 = p2.Test()

# %% [markdown]
# ## Part 1: Implementing Multi-Layer Perceptron
#
# ### 1. Simple Multi-Layer Perceptron

# %%
test_1.test()
# Out:
# Test Loss: 0.0019269858583998534

# %% [markdown]
# ### 2. Multi-Layer Perceptron with removed data cases

# %%
test_1.test_remove_case()
# Out:
# Test Loss: 0.0066522361553856685
# Test Loss: 0.003000701464037428
# Test Loss: 0.010853254891831176

# %% [markdown]
# ### 3. Multi-Layer Perceptron with different hidden layer neurons

# %%
test_1.test_hidden_dim_case()
# Out:
# Test Loss: 0.6633457171064078
# Test Loss: 0.0046056614278393
# Test Loss: 0.004553940933965945
# Test Loss: 0.00454467300432407
# Test Loss: 0.004046442694395246
# Test Loss: 0.0045215320324648286

# %% [markdown]
# ### 4. Multi-Layer Perceptron with random initialization

# %%
test_1.test_random_initial_weights()
# Out:
# Test Loss: 0.004698841032204579
# Test Loss: 0.004876072029095261
# Test Loss: 0.00474463209677256
# Test Loss: 0.004696022338054316
# Test Loss: 0.6901710995795679
# Test Loss: 0.008560988700166559
# Test Loss: 0.0057073379688187854
# Test Loss: 0.004692326800573752
# Test Loss: 0.004799790480461917
# Test Loss: 0.004749499061841266

# %% [markdown]
# ### 5. Approximated Gaussian function

# %%
test_1.test_gauss()
# Out:
# Test Loss: 0.0027454553730859262

# %% [markdown]
# ### 6. Encoder

# %%
test_1.test_encoder()
# Out:
# Test Loss: 0.05288195471840758
# Test Loss: 0.0004848060292175502

# %% [markdown]
# ## Part 2: MLP with PyTorch
#
# ### 1. Simple Multi-Layer Perceptron

# %%
test_2.test()
# Out:
# Early stopping at epoch 2100
# Test Loss: 0.08675389736890793

# %% [markdown]
# ### 2. Multi-Layer Perceptron with different hidden layer neurons

# %%
test_2.test_dim_cases()
# Out:
# Testing with h1=3, h2=2
# Early stopping at epoch 4653
# Test Loss: 0.08676338195800781
# Testing with h1=3, h2=4
# Early stopping at epoch 1479
# Test Loss: 0.08753561973571777
# Testing with h1=3, h2=6
# Early stopping at epoch 3622
# Test Loss: 0.08683472871780396
# Testing with h1=4, h2=2
# Early stopping at epoch 6530
# Test Loss: 0.08684177696704865
# Testing with h1=4, h2=4
# Early stopping at epoch 1453
# Test Loss: 0.08680596947669983
# Testing with h1=4, h2=6
# Early stopping at epoch 3152
# Test Loss: 0.08684474974870682
# Testing with h1=5, h2=2
# Early stopping at epoch 410
# Test Loss: 0.08991708606481552
# Testing with h1=5, h2=4
# Early stopping at epoch 1982
# Test Loss: 0.08695633709430695
# Testing with h1=5, h2=6
# Early stopping at epoch 1090
# Test Loss: 0.08682145923376083

# %% [markdown]
# ### 3. Train with Gaussian noise

# %%
test_2.test_gaussian_noise()
# Out:
# Testing with noise=0.05, h2=2
# Early stopping at epoch 4985
# Test Loss: 0.08731614053249359
# Testing with noise=0.05, h2=6
# Early stopping at epoch 2911
# Test Loss: 0.08681037276983261
# Testing with noise=0.05, h2=9
# Early stopping at epoch 1399
# Test Loss: 0.08694490790367126
# Testing with noise=0.15, h2=2
# Early stopping at epoch 1302
# Test Loss: 0.08699162304401398
# Testing with noise=0.15, h2=6
# Early stopping at epoch 4519
# Test Loss: 0.0873619019985199
# Testing with noise=0.15, h2=9
# Early stopping at epoch 2645
# Test Loss: 0.08712171763181686

# %% [markdown]
# ### 4. Train with different training data sizes (percentage)

# %%
test_2.test_training_percentage_case()
# Out:
# Testing with training percentage=0.2
# Early stopping at epoch 423
# Test Loss: 0.08687946945428848
# Testing with training percentage=0.4
# Early stopping at epoch 1891
# Test Loss: 0.08746714890003204
# Testing with training percentage=0.6
# Early stopping at epoch 1969
# Test Loss: 0.08698391169309616
# Testing with training percentage=0.8
# Early stopping at epoch 1395
# Test Loss: 0.08702164143323898
