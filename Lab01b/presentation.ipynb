# %% [markdown]
# # Lab 1b: Multi-Layer Perceptron
#
# Import the test classes from the two parts of the lab.

# %%
import Lab01b.part1 as p1
import Lab01b.part2 as p2

test_1 = p1.Test()
test_2 = p2.Test()

# %% [markdown]
# ## Part 1: Implementing Multi-Layer Perceptron
#
# ### 1. Simple Multi-Layer Perceptron

# %%
test_1.test()
# Out:
# Test Loss: 0.0027090188821996416

# %% [markdown]
# ### 2. Multi-Layer Perceptron with removed data cases

# %%
test_1.test_remove_case()
# Out:
# Test Loss: 0.0032079596878903933
# Test Loss: 0.017092394041394517
# Test Loss: 0.01966361397048791

# %% [markdown]
# ### 3. Multi-Layer Perceptron with different hidden layer neurons

# %%
test_1.test_hidden_dim_case()
# Out:
# Test Loss: 0.46360078991839726
# Test Loss: 0.011737640600812366
# Test Loss: 0.01176284255635462
# Test Loss: 0.011202894001391447
# Test Loss: 0.0112222442057419
# Test Loss: 0.013607140989845452

# %% [markdown]
# ### 4. Multi-Layer Perceptron with random initialization

# %%
test_1.test_random_initial_weights()
# Out:
# Test Loss: 0.012672162399506437
# Test Loss: 0.012467892930329924
# Test Loss: 0.01337313029369597
# Test Loss: 0.012365582108161527
# Test Loss: 0.013363897617705043
# Test Loss: 0.40621974647349496
# Test Loss: 0.01338641561340273
# Test Loss: 0.6950104082261324
# Test Loss: 0.012456018161062975
# Test Loss: 0.012804427546969782

# %% [markdown]
# ### 5. Approximated Gaussian function

# %%
test_1.test_gauss()
# Out:
# Test Loss: 0.0029719320688209893

# %% [markdown]
# ### 6. Encoder

# %%
test_1.test_encoder()
# Out:
# Test Loss: 0.04229970811330464
# Test Loss: 0.0003853694321618611

# %% [markdown]
# ## Part 2: MLP with PyTorch
#
# ### 1. Simple Multi-Layer Perceptron

# %%
test_2.test()
# Out:
# Early stopping at epoch 1079
# Test Loss: 0.07899804413318634

# %% [markdown]
# ### 2. Multi-Layer Perceptron with different hidden layer neurons

# %%
test_2.test_dim_cases()
# Out:
# Testing with h1=3, h2=2
# Early stopping at epoch 6146
# Test Loss: 0.07843682169914246
# Testing with h1=3, h2=4
# Early stopping at epoch 1646
# Test Loss: 0.0786004438996315
# Testing with h1=3, h2=6
# Early stopping at epoch 1856
# Test Loss: 0.07840165495872498
# Testing with h1=4, h2=2
# Early stopping at epoch 3518
# Test Loss: 0.07826941460371017
# Testing with h1=4, h2=4
# Early stopping at epoch 1441
# Test Loss: 0.07948952913284302
# Testing with h1=4, h2=6
# Early stopping at epoch 1716
# Test Loss: 0.0784539058804512
# Testing with h1=5, h2=2
# Early stopping at epoch 5247
# Test Loss: 0.07826452702283859
# Testing with h1=5, h2=4
# Early stopping at epoch 3191
# Test Loss: 0.07837419956922531
# Testing with h1=5, h2=6
# Early stopping at epoch 1511
# Test Loss: 0.07855428755283356

# %% [markdown]
# ### 3. Train with Gaussian noise

# %%
test_2.test_gaussian_noise()
# Out:
# Testing with noise=0.05, h2=2
# Early stopping at epoch 4897
# Test Loss: 0.07824154943227768
# Testing with noise=0.05, h2=6
# Early stopping at epoch 2375
# Test Loss: 0.07826744019985199
# Testing with noise=0.05, h2=9
# Early stopping at epoch 912
# Test Loss: 0.07839168608188629
# Testing with noise=0.15, h2=2
# Early stopping at epoch 3077
# Test Loss: 0.07797587662935257
# Testing with noise=0.15, h2=6
# Early stopping at epoch 1536
# Test Loss: 0.07814324647188187
# Testing with noise=0.15, h2=9
# Early stopping at epoch 1236
# Test Loss: 0.07793037593364716
