# %% [markdown]
# # Lab 1b: Multi-Layer Perceptron
#
# Import the test classes from the two parts of the lab.

# %%
import Lab01b.part1 as p1
import Lab01b.part2 as p2

test_1 = p1.Test()
test_2 = p2.Test()

# %% [markdown]
# ## Part 1: Implementing Multi-Layer Perceptron
#
# ### 1. Simple Multi-Layer Perceptron

# %%
test_1.test()
# Out:
# Test Loss: 0.002016311302626266

# %% [markdown]
# ### 2. Multi-Layer Perceptron with removed data cases

# %%
test_1.test_remove_case()
# Out:
# Test Loss: 0.001586638814004628
# Test Loss: 0.004942392860597454
# Test Loss: 0.008601793921280639

# %% [markdown]
# ### 3. Multi-Layer Perceptron with different hidden layer neurons

# %%
test_1.test_hidden_dim_case()
# Out:
# Test Loss: 0.7026742405830897
# Test Loss: 0.0023514716959845547
# Test Loss: 0.4320135897145541
# Test Loss: 0.0028069309621741477
# Test Loss: 0.002123306588893583
# Test Loss: 0.0020024954057633196

# %% [markdown]
# ### 4. Approximated Gaussian function

# %%
test_1.test_gauss()
# Out:
# Test Loss: 0.003206817813101281

# %% [markdown]
# ### 5. Encoder

# %%
test_1.test_encoder()
# Out:
# Test Loss: 0.049149418401673646
# Test Loss: 0.0004508751848795818

# %% [markdown]
# ## Part 2: MLP with PyTorch
#
# ### 1. Simple Multi-Layer Perceptron

# %%
test_2.test()
# Out:
# Early stopping at epoch 1292
# Test Loss: 0.08010396361351013

# %% [markdown]
# ### 2. Multi-Layer Perceptron with different hidden layer neurons

# %%
test_2.test_dim_cases()
# Out:
# Testing with h1=3, h2=2
# Early stopping at epoch 1436
# Test Loss: 0.08065887540578842
# Testing with h1=3, h2=4
# Early stopping at epoch 3205
# Test Loss: 0.08007416129112244
# Testing with h1=3, h2=6
# Early stopping at epoch 4089
# Test Loss: 0.08035049587488174
# Testing with h1=4, h2=2
# Early stopping at epoch 1805
# Test Loss: 0.08211687207221985
# Testing with h1=4, h2=4
# Early stopping at epoch 4898
# Test Loss: 0.08050455152988434
# Testing with h1=4, h2=6
# Early stopping at epoch 1960
# Test Loss: 0.08067376911640167
# Testing with h1=5, h2=2
# Early stopping at epoch 3164
# Test Loss: 0.08078911155462265
# Testing with h1=5, h2=4
# Early stopping at epoch 4822
# Test Loss: 0.0810486376285553
# Testing with h1=5, h2=6
# Early stopping at epoch 3813
# Test Loss: 0.08223264664411545

# %% [markdown]
# ### 3. Train with Gaussian noise

# %%
test_2.test_gaussian_noise()
# Out:
# Testing with noise=0.05, h2=2
# Early stopping at epoch 3535
# Test Loss: 0.0801062360405922
# Testing with noise=0.05, h2=6
# Early stopping at epoch 2082
# Test Loss: 0.08001808077096939
# Testing with noise=0.05, h2=9
# Early stopping at epoch 1467
# Test Loss: 0.07998146861791611
# Testing with noise=0.15, h2=2
# Early stopping at epoch 10701
# Test Loss: 0.08044850826263428
# Testing with noise=0.15, h2=6
# Early stopping at epoch 3411
# Test Loss: 0.079995296895504
# Testing with noise=0.15, h2=9
# Early stopping at epoch 1618
# Test Loss: 0.07994628697633743

# %%
test_2.test_gaussian_noise(regularization=0.0001)
