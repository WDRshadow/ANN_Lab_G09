# %% [markdown]
# # Lab 2: RBF and SOM
#
# Import the test classes from the two parts of the lab.

# %%
from Lab02.part1 import Test
from Lab02.part2 import TestSOM

p1 = Test()
p2 = TestSOM()

# %% [markdown]
# ## Part 1: Radial Basis Function Network
#
# ### 1. $Sin(2X)$
#
# Normal

# %%
p1.test_sin_2x()
# Out:
# Test Loss: 1.9819221641465604e-06

# %% [markdown]
# $Sin(2X)$ with noise

# %%
p1.test_sin_2x_gaussian()
# Out:
# Test Loss: 0.007556160450625963

# %% [markdown]
# $Sin(2X)$ with CL

# %%
p1.test_sin_2x_competitive_learning()
# Out:
# Test Loss: 8.557367652302807e-05

# %% [markdown]
# ### 2. $(2x)^2$
#
# Normal

# %%
p1.test_square_2x()
# Out:
# Test Loss: 0.010021923746541863

# %% [markdown]
# $(2x)^2$ with noise

# %%
p1.test_square_2x_gaussian()
# Out:
# Test Loss: 4785.293863193657

# %% [markdown]
# $(2x)^2$ with CL

# %%
p1.test_square_2x_competitive_learning()
# Out:
# Test Loss: 88.56923010781706

# %% [markdown]
# ### 3. Two dimension function

# %%
p1.test_2_dim_function()
# Out:
# Test Loss: 0.00041189001898930225

# %% [markdown]
# ## Part 2: Self-Organizing Maps
#
# ### 1. Animals

# %%
p2.test_animal()
# Out:
# Animal: antelop; Position: 0
# Animal: giraffe; Position: 1
# Animal: pig; Position: 1
# Animal: camel; Position: 2
# Animal: horse; Position: 3
# Animal: kangaroo; Position: 5
# Animal: elephant; Position: 6
# Animal: bat; Position: 8
# Animal: skunk; Position: 10
# Animal: ape; Position: 12
# Animal: cat; Position: 14
# Animal: lion; Position: 14
# Animal: dog; Position: 17
# Animal: bear; Position: 19
# Animal: hyena; Position: 20
# Animal: rat; Position: 23
# Animal: rabbit; Position: 24
# Animal: walrus; Position: 28
# Animal: crocodile; Position: 33
# Animal: seaturtle; Position: 33
# Animal: frog; Position: 36
# Animal: penguin; Position: 41
# Animal: ostrich; Position: 43
# Animal: duck; Position: 47
# Animal: pelican; Position: 48
# Animal: spider; Position: 56
# Animal: housefly; Position: 63
# Animal: moskito; Position: 66
# Animal: dragonfly; Position: 72
# Animal: grasshopper; Position: 75
# Animal: beetle; Position: 77
# Animal: butterfly; Position: 79

# %% [markdown]
# ### 2. Cities

# %%
p2.test_city()
# Out:
# /Users/wdrshadow/PycharmProjects/ANN_Lab_G09/utils/SOM.py:36: RuntimeWarning: overflow encountered in scalar divide
#   -distance_to_bmu ** 2 / (2 * self._sigma(iteration, max_iter) ** 2))
# /Users/wdrshadow/PycharmProjects/ANN_Lab_G09/utils/SOM.py:36: RuntimeWarning: divide by zero encountered in scalar divide
#   -distance_to_bmu ** 2 / (2 * self._sigma(iteration, max_iter) ** 2))
# /Users/wdrshadow/PycharmProjects/ANN_Lab_G09/utils/SOM.py:36: RuntimeWarning: invalid value encountered in scalar divide
#   -distance_to_bmu ** 2 / (2 * self._sigma(iteration, max_iter) ** 2))

# %% [markdown]
# ### 3. MP

# %%
p2.test_mp()
