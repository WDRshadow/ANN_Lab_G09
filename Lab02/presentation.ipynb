# %% [markdown]
# # Lab 2: RBF and SOM
#
# Import the test classes from the two parts of the lab.

# %%
from Lab02.part1 import Test
from Lab02.part2 import TestSOM

p1 = Test()
p2 = TestSOM()

# %% [markdown]
# ## Part 1: Radial Basis Function Network
#
# ### 1. $Sin(2X)$
#
# Normal

# %%
p1.test_sin_2x()
# Out:
# Test Loss: 3.808710815205795e-07

# %% [markdown]
# $Sin(2X)$ with noise

# %%
p1.test_sin_2x_gaussian()
# Out:
# Test Loss: 0.010919470472502486

# %% [markdown]
# $Sin(2X)$ with CL

# %%
p1.test_sin_2x_competitive_learning()
# Out:
# Test Loss: 0.00012707677834973796
# Test Loss: 1.7991239970508963e-05

# %% [markdown]
# ### 2. $(2x)^2$
#
# Normal

# %%
p1.test_square_2x()
# Out:
# Test Loss: 0.04018167630489703

# %% [markdown]
# $square(2x)$ with noise

# %%
p1.test_square_2x_gaussian()
# Out:
# Test Loss: 0.04018167630489703

# %% [markdown]
# $(2x)^2$ with CL

# %%
p1.test_square_2x_competitive_learning()
# Out:
# Test Loss: 0.04833134405085901
# Test Loss: 0.04418996939884889

# %% [markdown]
# Comparisons

# %%
p1.test_run_all_rbf_comparisons()

# %% [markdown]
# Different numbers of winners for competitive learning

# %%
p1.test_2x2_winners_cl()
# Out:
# Test Loss: 1066.529851614715
# Test Loss: 1.8444237618339547

# %% [markdown]
# ### 3. Two dimension function

# %%
p1.test_2_dim_function_2()

# %% [markdown]
# ## Part 2: Self-Organizing Maps
#
# ### 1. Animals

# %%
p2.test_animals()

# %% [markdown]
# ### 2. Cities

# %%
p2.test_city()
# Out:
# /Users/wdrshadow/PycharmProjects/ANN_Lab_G09/utils/SOM.py:36: RuntimeWarning: overflow encountered in scalar divide
#   -distance_to_bmu ** 2 / (2 * self._sigma(iteration, max_iter) ** 2))
# /Users/wdrshadow/PycharmProjects/ANN_Lab_G09/utils/SOM.py:36: RuntimeWarning: divide by zero encountered in scalar divide
#   -distance_to_bmu ** 2 / (2 * self._sigma(iteration, max_iter) ** 2))
# /Users/wdrshadow/PycharmProjects/ANN_Lab_G09/utils/SOM.py:36: RuntimeWarning: invalid value encountered in scalar divide
#   -distance_to_bmu ** 2 / (2 * self._sigma(iteration, max_iter) ** 2))

# %% [markdown]
# ### 3. MP

# %%
p2.test_mp()
