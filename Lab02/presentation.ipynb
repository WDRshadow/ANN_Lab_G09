# %% [markdown]
# # Lab 2: RBF and SOM
#
# Import the test classes from the two parts of the lab.

# %%
from Lab02.part1 import Test
from Lab02.part2 import TestSOM

p1 = Test()
p2 = TestSOM()

# %% [markdown]
# ## Part 1: Radial Basis Function Network
#
# ### 1. $Sin(2X)$
#
# Normal

# %%
p1.test_sin_2x()
# Out:
# Test Loss: 1.9819221641465604e-06

# %% [markdown]
# $Sin(2X)$ with noise

# %%
p1.test_sin_2x_gaussian()
# Out:
# Test Loss: 0.0005928444278451393

# %% [markdown]
# $Sin(2X)$ with CL

# %%
p1.test_sin_2x_competitive_learning()
# Out:
# Test Loss: 0.0001288602758578742

# %% [markdown]
# ### 2. $(2x)^2$
#
# Normal

# %%
p1.test_square_2x()
# Out:
# Test Loss: 0.010021923746541863

# %% [markdown]
# $(2x)^2$ with noise

# %%
p1.test_square_2x_gaussian()
# Out:
# Test Loss: 0.01519651500475818

# %% [markdown]
# $(2x)^2$ with CL

# %%
p1.test_square_2x_competitive_learning()
# Out:
# Test Loss: 24.426272990096706

# %% [markdown]
# ### 3. Two dimension function

# %%
p1.test_2_dim_function()
# Out:
# Test Loss: 0.00044756522764093277

# %% [markdown]
# ## Part 2: Self-Organizing Maps
#
# ### 1. Animals

# %%
p2.test_animal()
# Out:
# Animal: camel; Position: 0
# Animal: giraffe; Position: 0
# Animal: pig; Position: 1
# Animal: horse; Position: 2
# Animal: antelop; Position: 4
# Animal: kangaroo; Position: 6
# Animal: elephant; Position: 8
# Animal: rabbit; Position: 11
# Animal: ape; Position: 14
# Animal: cat; Position: 17
# Animal: lion; Position: 17
# Animal: bat; Position: 21
# Animal: rat; Position: 23
# Animal: skunk; Position: 24
# Animal: dog; Position: 27
# Animal: hyena; Position: 29
# Animal: bear; Position: 30
# Animal: walrus; Position: 34
# Animal: crocodile; Position: 40
# Animal: seaturtle; Position: 41
# Animal: frog; Position: 45
# Animal: pelican; Position: 52
# Animal: duck; Position: 53
# Animal: ostrich; Position: 58
# Animal: penguin; Position: 60
# Animal: spider; Position: 70
# Animal: housefly; Position: 78
# Animal: moskito; Position: 81
# Animal: butterfly; Position: 86
# Animal: beetle; Position: 91
# Animal: grasshopper; Position: 94
# Animal: dragonfly; Position: 98

# %% [markdown]
# ### 2. Cities

# %%
p2.test_city()
# Out:
# /Users/wdrshadow/PycharmProjects/ANN_Lab_G09/utils/SOM.py:36: RuntimeWarning: overflow encountered in scalar divide
#   -distance_to_bmu ** 2 / (2 * self._sigma(iteration, max_iter) ** 2))
# /Users/wdrshadow/PycharmProjects/ANN_Lab_G09/utils/SOM.py:36: RuntimeWarning: divide by zero encountered in scalar divide
#   -distance_to_bmu ** 2 / (2 * self._sigma(iteration, max_iter) ** 2))
# /Users/wdrshadow/PycharmProjects/ANN_Lab_G09/utils/SOM.py:36: RuntimeWarning: invalid value encountered in scalar divide
#   -distance_to_bmu ** 2 / (2 * self._sigma(iteration, max_iter) ** 2))

# %% [markdown]
# ### 3. MP

# %%
p2.test_mp()
